# %%
from pathlib import Path

# %%
import csv

# %%
csvpath = Path('Resources/budget_data.csv')

# %%
pnlstatement = []
just_months = []

# %%
line_num = 0

# %%
with open(csvpath, 'r') as csvfile:
    print(type(csvfile))
    csvreader = csv.reader(csvfile, delimiter = ',')
    print(type(csvreader))
    header = next(csvreader)
    line_num += 1
    print(header)
    for row in csvreader:
        #print(row)
        profitLoss = int(row[1])
        pnlstatement.append(profitLoss)
        months = row[0]
        just_months.append(months)
        print(pnlstatement)
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses']
# [867884]
# [867884, 984655]
# [867884, 984655, 322013]
# [867884, 984655, 322013, -69417]
# [867884, 984655, 322013, -69417, 310503]
# [867884, 984655, 322013, -69417, 310503, 522857]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353, 779806]
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353, 779806, -335203]
# ...

# %%
budget_data = []
net_change_list = []
net_change = 0
total_months = 0
net_profit = 0 
with open(csvpath, 'r') as csvfile:
    # print(type(csvfile))
    csvreader = csv.reader(csvfile, delimiter = ',')
    # print(type(csvreader))
    header = next(csvreader)
    total_months += 1
    # print(header)
    first_row = next(csvreader)
    prev_amt = int(first_row[1])
    # print(first_row)
    # print(prev_amt)
    for all_data in csvreader:
        net_change = int(all_data[1]) - prev_amt
        net_change_list.append(net_change)
        
        prev_amt = int(all_data[1])
        
        # Count the months
        total_months += 1
net_profit = sum(pnlstatement)
greatest_increase = max(net_change_list)
greatest_decrease = min(net_change_list)
        # greatest inc and dec
        
        # #print(row)
        # data = all_data
        # budget_data.append(data)
        # # print(budget_data)
        
avg_change = sum(net_change_list) / len(net_change_list)


print(f'Financial Analysis\n------------------\nTotal Months: {total_months}\nTotal: ${net_profit}\nAverage Change: ${round(avg_change, 2)}\nGreatest Increase in Profits: {just_months[net_change_list.index(greatest_increase)+1]} (${greatest_increase})\nGreatest Decrease in Profits: {just_months[net_change_list.index(greatest_decrease)+1]} (${greatest_decrease})\n---  ')
# Out:
# Financial Analysis
# ------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
# ---

# %%
print(budget_data)
# Out:
# [['Jan-2010', '867884'], ['Feb-2010', '984655'], ['Mar-2010', '322013'], ['Apr-2010', '-69417'], ['May-2010', '310503'], ['Jun-2010', '522857'], ['Jul-2010', '1033096'], ['Aug-2010', '604885'], ['Sep-2010', '-216386'], ['Oct-2010', '477532'], ['Nov-2010', '893810'], ['Dec-2010', '-80353'], ['Jan-2011', '779806'], ['Feb-2011', '-335203'], ['Mar-2011', '697845'], ['Apr-2011', '793163'], ['May-2011', '485070'], ['Jun-2011', '584122'], ['Jul-2011', '62729'], ['Aug-2011', '668179'], ['Sep-2011', '899906'], ['Oct-2011', '834719'], ['Nov-2011', '132003'], ['Dec-2011', '309978'], ['Jan-2012', '-755566'], ['Feb-2012', '1170593'], ['Mar-2012', '252788'], ['Apr-2012', '1151518'], ['May-2012', '817256'], ['Jun-2012', '570757'], ['Jul-2012', '506702'], ['Aug-2012', '-1022534'], ['Sep-2012', '475062'], ['Oct-2012', '779976'], ['Nov-2012', '144175'], ['Dec-2012', '542494'], ['Jan-2013', '359333'], ['Feb-2013', '321469'], ['Mar-2013', '67780'], ['Apr-2013', '471435'], ['May-2013', '565603'], ['Jun-2
# ...
